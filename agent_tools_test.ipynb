# %%
from pola_tools import PolaTool
from pokemontcgsdk import Card
cards = [Card.find('sv9-155'), Card.find("sm7-148a")]
tool = PolaTool()
results = tool.classify_trainers(cards)
print(results)
# Out:
# c:\Users\Asa\OneDrive\UNC Grad School\Data 720\Final-Project\pola_tools.py:123: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   classification_chain = LLMChain(
# c:\Users\Asa\OneDrive\UNC Grad School\Data 720\Final-Project\pola_tools.py:129: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   result = classification_chain.run(card_texts=batch)
# [{'category': 'Consistency', 'subtype': 'Draw'}, {'category': 'Both', 'subtype': 'Draw'}]

# %%
# testing with the whole cube
import pickle

with open("example_cube_cards.pkl", 'rb') as f:
    cards = pickle.load(f)
trainer_cards = [card for card in cards if card.supertype == "Trainer"]
trainer_cards[0].name
# Out:
# 'Arezu'

# %%
# trying to classify all trainers
tool = PolaTool(gemini_model='gemini-2.0-flash-lite')
results = tool.classify_trainers(trainer_cards, batch_size=5)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\Asa\OneDrive\UNC Grad School\Data 720\Final-Project\pola_tools.py:33, in CardClassificationOutputParser.parse(self, text)
#      32 try:
# ---> 33     data = json.loads(clean)
#      34     return data
#
# File c:\Users\Asa\miniconda3\envs\dev\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\Asa\miniconda3\envs\dev\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
# ...

# %%
for i, result in enumerate(results):
    print(i, result)
# Out:
# 0 {'category': 'Consistency', 'subtype': 'Search'}
# 1 {'category': 'Consistency', 'subtype': 'Search'}
# 2 {'category': 'Utility', 'subtype': None}
# 3 {'category': 'Consistency', 'subtype': 'Pick'}
# 4 {'category': 'Consistency', 'subtype': 'Pick'}
# 5 {'category': 'Both', 'subtype': 'Draw'}
# 6 {'category': 'Utility', 'subtype': None}
# 7 {'category': 'Consistency', 'subtype': 'Search'}
# 8 {'category': 'Utility', 'subtype': None}
# 9 {'category': 'Both', 'subtype': 'Draw'}
# 10 {'category': 'Utility', 'subtype': None}
# 11 {'category': 'Utility', 'subtype': None}
# 12 {'category': 'Consistency', 'subtype': 'Search'}
# 13 {'category': 'Consistency', 'subtype': 'Search'}
# 14 {'category': 'Consistency', 'subtype': 'Search'}
# 15 {'category': 'Both', 'subtype': 'Draw'}
# 16 {'category': 'Consistency', 'subtype': 'Search'}
# 17 {'category': 'Both', 'subtype': 'Draw'}
# 18 {'category': 'Both', 'subtype': 'Draw'}
# 19 {'category': 'Both', 'subtype': 'Draw'}
# ...

# %%
# for i, result in enumerate(results):
#     print(f"{i}: {trainer_cards[i].name} : {result}")
